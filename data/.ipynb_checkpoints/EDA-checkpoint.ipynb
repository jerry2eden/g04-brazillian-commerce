# %%
#importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
from googletrans import Translator

# %matplotlib inline

# %%
#identifying the datasets in local storage

dataset_files = glob.glob('*.csv')
dataset_files
# Out:
# ['olist_customers_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_products_dataset.csv',
#  'olist_sellers_dataset.csv',
#  'product_category_name_translation.csv']

# %%
datasets_dict = {}

# %%
#loading the dataset files into pandas dataframes

for file in dataset_files:
    dataset_name = file.strip('dataset.csv')+'df'
    df = pd.read_csv(file)
    datasets_dict[dataset_name] = df

# %%
datasets_dict.keys()
# Out:
# dict_keys(['olist_customers_df', 'olist_geolocation_df', 'olist_orders_df', 'olist_order_items_df', 'olist_order_payments_df', 'olist_order_reviews_df', 'olist_products_df', 'olist_sellers_df', 'product_category_name_translationdf'])

# %%
datasets_dict['olist_customers_df']
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
customers_df = datasets_dict['olist_customers_df']
geolocation_df = datasets_dict['olist_geolocation_df']
orders_df = datasets_dict['olist_orders_df']
order_items_df = datasets_dict['olist_order_items_df']
order_payments_df = datasets_dict['olist_order_payments_df']
order_reviews_df = datasets_dict['olist_order_reviews_df']
products_df = datasets_dict['olist_products_df']
sellers_df = datasets_dict['olist_sellers_df']
product_category_name_translation_df = datasets_dict['product_category_name_translationdf']

# %%
geolocation_df
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
products_df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
product_category_name_translation_df
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
order_payments_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
sellers_df
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
order_reviews_df
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# # Creating merged DataFrames that would come in handy later:
#
# Used left-join on all merges so that we don't lose important information from the datasets on the left where the datasets on the right don't have corresponding information.

# %%
customers_order_df = pd.merge(customers_df, orders_df, on='customer_id', how='left')
customers_order_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
for col in ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']:
    customers_order_df[col] = pd.to_datetime(customers_order_df[col])

# %%
customers_order_items_df = pd.merge(customers_order_df, order_items_df, on='order_id', how='left')
customers_order_items_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 113420  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 113421  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 113422  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 113423  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 113424  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
customers_order_items_df = pd.merge(customers_order_items_df, products_df, on='product_id', how='left')
customers_order_items_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 113420  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 113421  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 113422  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 113423  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 113424  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
customers_order_items_df = pd.merge(customers_order_items_df, product_category_name_translation_df, on='product_category_name', how='left')
customers_order_items_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 113420  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 113421  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 113422  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 113423  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 113424  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
customers_order_items_df = pd.merge(customers_order_items_df, sellers_df, on='seller_id', how='left')
customers_order_items_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 113420  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 113421  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 113422  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 113423  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 113424  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
customers_order_items_review_df = pd.merge(customers_order_items_df, order_reviews_df, on='order_id', how='left')
customers_order_items_review_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 114095  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 114096  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 114097  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 114098  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 114099  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
customers_order_items_review_df.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'order_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'order_item_id', 'product_id',
#        'seller_id', 'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp'],
#       dtype='object')

# %%
olist_df = customers_order_items_review_df.drop(columns=['customer_city',
                                                         'customer_state',
                                                         'order_approved_at',
                                                         'order_delivered_carrier_date',
                                                         'shipping_limit_date',
                                                         'product_category_name',
                                                         'product_name_lenght',
                                                         'product_description_lenght',
                                                         'product_weight_g',
                                                         'product_length_cm',
                                                         'product_height_cm',
                                                         'product_width_cm',
                                                         'seller_city',
                                                         'seller_state',
                                                         'review_creation_date',
                                                         'review_answer_timestamp'])
olist_df
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 114095  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 114096  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 114097  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 114098  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 114099  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
olist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114100 entries, 0 to 114099
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    114100 non-null  object
#  1   customer_unique_id             114100 non-null  object
#  2   customer_zip_code_prefix       114100 non-null  int64
#  3   order_id                       114100 non-null  object
#  4   order_status                   114100 non-null  object
#  5   order_purchase_timestamp       114100 non-null  datetime64[ns]
#  6   order_delivered_customer_date  110847 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  114100 non-null  datetime64[ns]
#  8   order_item_id                  113322 non-null  float64
#  9   product_id                     113322 non-null  object
#  10  seller_id                      113322 non-null  object
# ...

# %% [markdown]
# # Exploring the dataset

# %% [markdown]
# Our dataset contains orders made between **4th September, 2016** and **17th October, 2018.**
#
# A total of about **773 days.**

# %% [markdown]
# We have a total of **99441 unique orders** in our dataset.

# %% [markdown]
# Some *orders* are *missing* from the **order_items** dataset.
#
# These orders number **775** in total and further investigation shows that their order statuses are mostly either *'unavailable'* or *'canceled'*.
#
# *These orders being missing from the order_items dataset means that we can't find the products, product prices, freight values, sellers nor product categories linked to these orders.*

# %%
olist_df.order_purchase_timestamp.min()
# Out:
# Timestamp('2016-09-04 21:15:19')

# %%
olist_df.order_purchase_timestamp.max()
# Out:
# Timestamp('2018-10-17 17:30:18')

# %%
olist_df.order_purchase_timestamp.max() - olist_df.order_purchase_timestamp.min()
# Out:
# Timedelta('772 days 20:14:59')

# %%
orders_df.order_id.nunique()
# Out:
# 99441

# %%
order_items_df.order_id.nunique()
# Out:
# 98666

# %%
missing_orders = []
available_orders = []
set_1 = set(orders_df['order_id'].tolist())
set_2 = set(order_items_df['order_id'].tolist())


for order in set_1:
    if order in set_2:
        available_orders.append(order)
    else:
        missing_orders.append(order)

# %%
len(available_orders)    #this matches the count of unique order_ids in the order_items dataset
# Out:
# 98666

# %%
len(missing_orders)    #this is the number of order_ids in the orders dataset that are missing from the order_items dataset
# Out:
# 775

# %%
missing_orders_df = pd.DataFrame(columns=orders_df.columns)
for order in missing_orders:
    temp_df = orders_df[orders_df['order_id']==order]
    missing_orders_df = missing_orders_df.append(temp_df, ignore_index=True)
missing_orders_df['order_status'].value_counts()
# Out:
# unavailable    603
# canceled       164
# created          5
# invoiced         2
# shipped          1
# Name: order_status, dtype: int64

# %% [markdown]
# ### Analysing the volume of orders by States and Cities

# %% [markdown]
# Our orders come from a total of **4119 different Cities in 27 different States**.
#
# The top 5 Cities with the most orders are:
# 1. **Sau Paulo**
# 2. **Rio de Janiero**
# 3. **Belo Horizonte**
# 4. **Brasilia**
# 5. **Curitiba**
#
# While the top 5 States with the most orders are:
# 1. **Sao Paulo (SP)**
# 2. **Rio de Janeiro (RJ)**
# 3. **Minas Gerais (MG)**
# 4. **Rio Grande do Sul (RS)**
# 5. **Parana (PR)**
#
# *The distriibution of unique customers also follows this order.*

# %%
#number of cities our orders come from
customers_order_df['customer_city'].nunique()
# Out:
# 4119

# %%
#volume of orders from each city
customers_order_df['customer_city'].value_counts()
# Out:
# sao paulo           15540
# rio de janeiro       6882
# belo horizonte       2773
# brasilia             2131
# curitiba             1521
#                     ...
# lamarao                 1
# simao pereira           1
# rio rufino              1
# angelo frechiani        1
# joaquim pires           1
# Name: customer_city, Length: 4119, dtype: int64

# %%
#number of States our orders come from
customers_order_df['customer_state'].nunique()
# Out:
# 27

# %%
#volume of orders from each State
customers_order_df['customer_state'].value_counts()
# Out:
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_state, dtype: int64

# %% [markdown]
# The above analyses the total orders.
# Since we have repeat customers, we would like to know the number of unique customers from each City and State.

# %% [markdown]
# **Analysing unique customers:**

# %%
#number of unique customers that placed an order from each city
customers_order_df[['customer_unique_id', 'customer_city', 'customer_state']].groupby('customer_unique_id').max()['customer_city'].value_counts()
# Out:
# sao paulo             14977
# rio de janeiro         6616
# belo horizonte         2667
# brasilia               2065
# curitiba               1463
#                       ...
# sao jose do serido        1
# capela nova               1
# terra nova                1
# riachuelo                 1
# bodo                      1
# Name: customer_city, Length: 4119, dtype: int64

# %%
#number of unique customers that placed an order from each State
customers_order_df[['customer_unique_id', 'customer_city', 'customer_state']].groupby('customer_unique_id').max()['customer_state'].value_counts()
# Out:
# SP    40302
# RJ    12380
# MG    11251
# RS     5276
# PR     4878
# SC     3530
# BA     3275
# DF     2071
# ES     1963
# GO     1950
# PE     1605
# CE     1312
# PA      949
# MT      876
# MA      725
# MS      693
# PB      517
# PI      482
# RN      474
# AL      400
# SE      342
# TO      273
# RO      240
# AM      143
# AC       77
# AP       67
# RR       45
# Name: customer_state, dtype: int64

# %% [markdown]
# # Analysing the products sold

# %% [markdown]
# **Total value** of all orders within the duration in view = **_R$13,591,643.7_**
#
# The top five (5) **most sold products** (by product id) are:
# 1. _aca2eb7d00ea1a7b8ebd4e68314663af **(527 units)**_
# 2. _99a4788cb24856965c36a24e339b6058 **(488 units)**_
# 3. _422879e10f46682990de24d770e7f83d **(484 units)**_
# 4. _389d119b48cf3043d311335e499d9c6b **(392 units)**_
# 5. _368c6c730842d78016ad823897a372db **(388 units)**_
#
# The **most expensive product** per unit is *489ae2aa008f021502940f251d4cce7f*  which costs **R\\$6735.0** and has a freight value of **R\\$194.31**
#
# The product which has brought in the most money during the period under review is;
# _bb50f2e236e5eea0100680137654686c_ with a total value of **R\\$63885.0** and a total freight value of **R\\$3721.1**

# %% [markdown]
# Our top 5 **repeat unique customers** are:
#
# 1. 8d50f5eadf50201ccdcedfb9e2ac8455    (**17 orders**)
# 2. 3e43e6105506432c953e165fb2acf44c     (**9 orders**)
# 3. ca77025e7201e3b30c44b472ff346268     (**7 orders**)
# 4. 6469f99c1f9dfae7733b25662e7f1782     (**7 orders**)
# 5. 1b6c7548a2a1f9037c1fd3ddfed95f33     (**7 orders**)

# %% [markdown]
# The **top five (5) product categories** that bring in the **most money** are:
# 1. **health_beauty (R\\$1258681.34)**
# 2. **watches_gifts (R\\$1205005.68)**
# 3. **bed_bath_table (R\\$1036988.68)**
# 4. **sports_leisure (R\\$988048.97)**
# 5. **computers_accessories (R\\$911954.32)**
#
# The **five product categories** that bring in the **least money** are:
# 1. **security_and_services (R\\$283.29)**
# 2. **fashion_childrens_clothes (R\\$569.85)**
# 3. **cds_dvds_musicals (R\\$730.00)**
# 4. **home_comfort_2 (R\\$760.27)**
# 5. **flowers (R\\$1110.04)**

# %% [markdown]
# The **top 5 product categories** with the **most number of orders** are:
# 1. **bed_bath_table (11115 orders)**
# 2. **health_beauty (9670 orders)**
# 3. **sports_leisure (8641 orders)**
# 4. **furniture_decor (8334 orders)**
# 5. **computers_accessories (7827 orders)**
#
# The **five product categories** with the least number of order are:
# 1. **security_and_services (2 orders)**
# 2. **fashion_childrens_clothes (8 orders)**
# 3. **la_cuisine (14 orders)**
# 4. **cds_dvds_musicals (14 orders)**
# 5. **arts_and_craftmanship (24 orders)**

# %%
#checking for total value of sales for the duration in our dataset
customers_order_items_df['price'].sum()
# Out:
# 13591643.7

# %%
#checking for the number of occurences of each product
customers_order_items_df.product_id.value_counts()
# Out:
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
#                                    ...
# de26d4014234181730a1143f75dad0e7      1
# 278b3c6462e86b4556b99989513ddf73      1
# 4dda033e39cdc37ce2932b7ba6e8a0f7      1
# 8fbf10c92c593a27da5034795db5d8b6      1
# 5aa8137e4896e7f017ab4d84c42cb784      1
# Name: product_id, Length: 32951, dtype: int64

# %%
#checking total price and frieght value of each product
order_items_by_product_df = order_items_df.groupby(['product_id']).sum()
order_items_by_product_df.drop(columns=['order_item_id'], inplace=True)
order_items_by_product_df
# Out:
#                                    price  freight_value
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38  101.65          18.59
# 00088930e925c41fd95ebfe695fd2655  129.90          13.93
# 0009406fd7479715e4bef61dd91f2462  229.00          13.10
# 000b8f95fcb9e0096488278317764d19  117.80          39.20
# 000d9be29b5207b54e86aa1b1ac54872  199.00          19.27
# ...                                  ...            ...
# fff6177642830a9a94a0f2cba5e476d1  229.98          55.41
# fff81cc3158d2725c0655ab9ba0f712c   90.00           7.89
# fff9553ac224cec9d15d49f5a263411f   32.00          11.85
# fffdb2d0ec8d6a61f0a0a0db3f25b441  169.95          58.87
# fffe9eeff12fcbd74a2f2b007dde0c58  249.99          53.88
#
# [32951 rows x 2 columns]

# %%
#checking for the product with the highest price
order_items_df[order_items_df['price'] == order_items_df['price'].max()]
# Out:
#                               order_id  order_item_id  \
# 3556  0812eb902a67711a1cb742b3cdaa65ae              1
#
#                             product_id                         seller_id  \
# 3556  489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
#
#       shipping_limit_date   price  freight_value
# 3556  2017-02-16 20:37:36  6735.0         194.31

# %%
#checking for the product that has brought in the most money
order_items_by_product_df[order_items_by_product_df['price'] == order_items_by_product_df['price'].max()]
# Out:
#                                     price  freight_value
# product_id
# bb50f2e236e5eea0100680137654686c  63885.0         3721.1

# %%
#checking for repeat customers
customers_df.customer_unique_id.value_counts().head(50)
# Out:
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 6469f99c1f9dfae7733b25662e7f1782     7
# ca77025e7201e3b30c44b472ff346268     7
# dc813062e0fc23409cd255f7f53c7074     6
# f0e310a6839dce9de1638e0fe5ab282a     6
# 12f5d6e1cbf93dafd9dcc19095df0b3d     6
# 63cfc61cee11cbe306bff5857d00bfe4     6
# de34b16117594161a6a89c50b289d35a     6
# 47c1a3033b8b77b3ab6e109eb4d5fdf3     6
# 394ac4de8f3acb14253c177f0e15bc58     5
# 4e65032f1f574189fb793bac5a867bbc     5
# 56c8638e7c058b98aae6d74d2dd6ea23     5
# 35ecdf6858edc6427223b64804cf028e     5
# 74cb1ad7e6d5674325c1f99b5ea30d82     5
# fe81bb32c243a86b2f86fbf053fe6140     5
# b4e4f24de1e8725b74e4a1f4975116ed     5
# 5e8f38a9a1c023f3db718edcf926a2db     5
# d3359a56d96666ac0c21bb01e7a61c95     4
# f34cd7fd85a1f8baff886edf09567be3     4
# a7657330b1c135f3acd420326e335b2c     4
# a0abd26659c9914690cbd3320d39fd96     4
# 083ca1aa470c280236380973a48f77c6     4
# ...

# %%
#the distribution of number of items in each order
olist_df[['order_id', 'order_item_id']].groupby(['order_id']).max()['order_item_id'].value_counts().sort_index()
# Out:
# 1.0     88863
# 2.0      7516
# 3.0      1322
# 4.0       505
# 5.0       204
# 6.0       198
# 7.0        22
# 8.0         8
# 9.0         3
# 10.0        8
# 11.0        4
# 12.0        5
# 13.0        1
# 14.0        2
# 15.0        2
# 20.0        2
# 21.0        1
# Name: order_item_id, dtype: int64

# %% [markdown]
# Most orders contain a single item (88863 orders).
# The highest number of items in a single order is 21. There are 2 orders with 20 items in each.

# %%
#checking how much money each product category brought in
customers_order_items_df.groupby('product_category_name_english').sum()['price'].sort_values(ascending=False)
# Out:
# product_category_name_english
# health_beauty                1258681.34
# watches_gifts                1205005.68
# bed_bath_table               1036988.68
# sports_leisure                988048.97
# computers_accessories         911954.32
#                                 ...
# flowers                         1110.04
# home_comfort_2                   760.27
# cds_dvds_musicals                730.00
# fashion_childrens_clothes        569.85
# security_and_services            283.29
# Name: price, Length: 71, dtype: float64

# %%
customers_order_items_df.groupby('product_category_name_english').sum()['price'].sort_values(ascending=False).plot(kind='bar', figsize=(16,9));

# %%
#checking how many orders each product category got in the period under review
customers_order_items_df.groupby('product_category_name_english').count()['product_id'].sort_values(ascending=False)
# Out:
# product_category_name_english
# bed_bath_table               11115
# health_beauty                 9670
# sports_leisure                8641
# furniture_decor               8334
# computers_accessories         7827
#                              ...
# arts_and_craftmanship           24
# cds_dvds_musicals               14
# la_cuisine                      14
# fashion_childrens_clothes        8
# security_and_services            2
# Name: product_id, Length: 71, dtype: int64

# %%
customers_order_items_df.groupby('product_category_name_english').count()['product_id'].sort_values(ascending=False).plot(kind='bar', figsize=(16,9));

# %% [markdown]
# **Time Series Analysis of the orders:**

# %%
time_series_df = customers_order_items_df.set_index('order_purchase_timestamp')

# %%
#value of orders with respect to time

# %%
price_time_series_df = time_series_df[['price', 'freight_value']]
price_time_series_df = price_time_series_df.resample('D').sum()
price_time_series_df
# Out:
#                           price  freight_value
# order_purchase_timestamp
# 2016-09-04                72.89          63.34
# 2016-09-05                59.50          15.56
# 2016-09-06                 0.00           0.00
# 2016-09-07                 0.00           0.00
# 2016-09-08                 0.00           0.00
# ...                         ...            ...
# 2018-10-13                 0.00           0.00
# 2018-10-14                 0.00           0.00
# 2018-10-15                 0.00           0.00
# 2018-10-16                 0.00           0.00
# 2018-10-17                 0.00           0.00
#
# [774 rows x 2 columns]

# %%
price_time_series_df['price'].sum()    #should still be equal to the total value before resampling
# Out:
# 13591643.700000018

# %%
price_moving_average = price_time_series_df['price'].rolling(7).mean()

# %%
plt.close()

# %%
plt.figure(figsize=(16, 9))
plt.plot(price_time_series_df.index, price_time_series_df['price'])
plt.plot(price_moving_average, color='r');

# %% [markdown]
# We see a spike in money earned on a particular day towards the end of the year.

# %% [markdown]
# Looking at this a bit further;

# %%
price_time_series_df['price'].idxmax()
# Out:
# Timestamp('2017-11-24 00:00:00', freq='D')

# %% [markdown]
# The date of this spike in revenue is 24th November, 2017. Incidentally, this is also the date for Black Friday that year. The Black Friday sales on the Olist platform brought in a huge surge in orders which in turn corresponds to a huge surge in revenue.
#
# link to verify date: https://www.google.com/search?client=firefox-b-d&q=black+friday+2017

# %% [markdown]
# There is a steady general increase in revenue generated with time. We have a dip and flatline at the end of our graph because our has no price information for most of the orders carried out after August 2018.

# %% [markdown]
# Revenue dips around the turn of the year 2017 - 2018 with two other noticeable dips in June and July 2018.

# %%
#checking the date of the dip in revenue in July 2018
price_time_series_df['2018-7']['price'].idxmin()
# Out:
# Timestamp('2018-07-07 00:00:00', freq='D')

# %%
#checking price infor for the month of August in 2018
price_time_series_df['2018-8']
# Out:
#                              price  freight_value
# order_purchase_timestamp
# 2018-08-01                40553.80        7877.23
# 2018-08-02                38462.26        7163.40
# 2018-08-03                42075.18        7442.40
# 2018-08-04                35511.96        5715.84
# 2018-08-05                35583.76        6688.31
# 2018-08-06                56427.39        9433.03
# 2018-08-07                49178.98        9115.40
# 2018-08-08                43333.07        8027.43
# 2018-08-09                40040.28        6694.58
# 2018-08-10                33424.73        6160.56
# 2018-08-11                25960.93        4604.80
# 2018-08-12                31524.21        5215.54
# 2018-08-13                38613.13        7263.78
# 2018-08-14                44192.84        7278.53
# 2018-08-15                45574.04        6784.61
# 2018-08-16                35670.61        6546.70
# 2018-08-17                31730.67        5908.32
# ...

# %%
#checking price infor for the month of September in 2018
price_time_series_df['2018-9']
# Out:
#                           price  freight_value
# order_purchase_timestamp
# 2018-09-01                  0.0           0.00
# 2018-09-02                  0.0           0.00
# 2018-09-03                145.0          21.46
# 2018-09-04                  0.0           0.00
# 2018-09-05                  0.0           0.00
# 2018-09-06                  0.0           0.00
# 2018-09-07                  0.0           0.00
# 2018-09-08                  0.0           0.00
# 2018-09-09                  0.0           0.00
# 2018-09-10                  0.0           0.00
# 2018-09-11                  0.0           0.00
# 2018-09-12                  0.0           0.00
# 2018-09-13                  0.0           0.00
# 2018-09-14                  0.0           0.00
# 2018-09-15                  0.0           0.00
# 2018-09-16                  0.0           0.00
# 2018-09-17                  0.0           0.00
# 2018-09-18                  0.0           0.00
# ...

# %%
#checking price infor for the month of October in 2018
price_time_series_df['2018-10']
# Out:
#                           price  freight_value
# order_purchase_timestamp
# 2018-10-01                  0.0            0.0
# 2018-10-02                  0.0            0.0
# 2018-10-03                  0.0            0.0
# 2018-10-04                  0.0            0.0
# 2018-10-05                  0.0            0.0
# 2018-10-06                  0.0            0.0
# 2018-10-07                  0.0            0.0
# 2018-10-08                  0.0            0.0
# 2018-10-09                  0.0            0.0
# 2018-10-10                  0.0            0.0
# 2018-10-11                  0.0            0.0
# 2018-10-12                  0.0            0.0
# 2018-10-13                  0.0            0.0
# 2018-10-14                  0.0            0.0
# 2018-10-15                  0.0            0.0
# 2018-10-16                  0.0            0.0
# 2018-10-17                  0.0            0.0

# %%
#quantity of orders with respect to time

# %%
orders_time_series_df = time_series_df[['order_id', 'price']]
orders_time_series_df = orders_time_series_df.resample('D').count()
orders_time_series_df
# Out:
#                           order_id  price
# order_purchase_timestamp
# 2016-09-04                       2      2
# 2016-09-05                       1      1
# 2016-09-06                       0      0
# 2016-09-07                       0      0
# 2016-09-08                       0      0
# ...                            ...    ...
# 2018-10-13                       0      0
# 2018-10-14                       0      0
# 2018-10-15                       0      0
# 2018-10-16                       1      0
# 2018-10-17                       1      0
#
# [774 rows x 2 columns]

# %%
orders_time_series_df['order_id'].sum()    #should still be equal to the number of ordered items (remember some orders have multiple items)
# Out:
# 113425

# %%
orders_moving_average = orders_time_series_df['order_id'].rolling(7).mean()

# %%
plt.close()

# %%
plt.figure(figsize=(16, 9))
plt.plot(orders_time_series_df.index, orders_time_series_df['order_id'])
plt.plot(orders_moving_average, color='r');

# %% [markdown]
# The graph of orders is similar to that of the revenue graph (as expected).

# %%
#checking how long it usually takes for orders to get approved after they've been made.

((customers_order_df['order_approved_at'] - customers_order_df['order_purchase_timestamp']).dt.days).value_counts().sort_index()
# Out:
# 0.0      81861
# 1.0      12254
# 2.0       2904
# 3.0       1491
# 4.0        397
# 5.0        262
# 6.0         31
# 7.0         17
# 8.0         13
# 9.0          3
# 10.0        14
# 11.0         5
# 12.0        15
# 13.0         2
# 16.0         1
# 23.0         3
# 28.0         1
# 30.0         2
# 32.0         3
# 60.0         1
# 187.0        1
# dtype: int64

# %% [markdown]
# As we can see, most orders are approved less than 24hrs after they've been made.
# We see a few orders that have taken up to a month to get approved and a couple that took even longer.

# %%
#checking how long it usually takes for orders to get delivered to the customer.

((customers_order_df['order_delivered_customer_date'] - customers_order_df['order_purchase_timestamp']).dt.days).value_counts().sort_index()
# Out:
# 0.0        13
# 1.0      1572
# 2.0      3168
# 3.0      3849
# 4.0      4828
#          ...
# 191.0       1
# 194.0       3
# 195.0       1
# 208.0       1
# 209.0       1
# Length: 146, dtype: int64

# %%
(((customers_order_df['order_delivered_customer_date'] - customers_order_df['order_purchase_timestamp']).dt.days).value_counts().sort_index()).plot(figsize=(32,18), kind='bar');

# %% [markdown]
# As we can see, most orders are delivered just a few days after they are placed.
# A few orders take months to complete though.

# %%
#checking the difference between the estimated delivery customers are given and when they actually receive their orders.

(((customers_order_df['order_estimated_delivery_date'] - customers_order_df['order_delivered_customer_date']).dt.days).value_counts().sort_index()).plot(figsize=(32,18), kind='bar');

# %%
((customers_order_df['order_estimated_delivery_date'] - customers_order_df['order_delivered_customer_date']).dt.days).value_counts().head(50)
# Out:
#  13.0    7126
#  12.0    5963
#  14.0    5345
#  6.0     4837
#  7.0     4828
#  9.0     4646
#  8.0     4626
#  10.0    4619
#  11.0    4556
#  15.0    3903
#  5.0     3625
#  16.0    3412
#  17.0    3128
#  19.0    2960
#  20.0    2810
#  18.0    2712
#  4.0     2219
#  3.0     1917
#  21.0    1845
#  2.0     1731
#  1.0     1550
#  0.0     1462
# -1.0     1292
#  22.0    1263
#  23.0    1067
#  24.0     913
# -2.0      825
#  26.0     816
#  25.0     793
#  27.0     753
# -3.0      545
# -4.0      500
#  28.0     492
# -8.0      483
# -5.0      453
# -6.0      447
# -7.0      419
#  29.0     377
# -9.0      336
#  30.0     304
#  31.0     277
#  32.0     261
#  34.0     256
#  33.0     247
# -10.0     227
# -11.0     207
# -14.0     196
# -12.0     181
# -15.0     171
#  35.0     168
# dtype: int64

# %% [markdown]
# This shows us that orders are usually delivered before the Estimated delivery dates customers are given.
#
# There are almost 1300 orders that were delivered a day late. Over 800 deliveries were 2 days late. In general, the late deliveries are a few days. Most orders are completed well before estimated delivery dates. The frequency of late deliveries might be a cause for concern though as it could affect customer satisfaction.

# %% [markdown]
# Things to explore:
# * Analyse the cost of delivery with respect to product price and weight.
# * See if the length of product description has a relationship with the number of orders and also the review score.
# * Analyse Payments methods

# %%
order_reviews_df.review_score.value_counts()

# %%
order_reviews_df.order_id.value_counts().head(556)

# %%
olist_df.groupby(['product_id']).mean()['review_score'].sort_values(ascending=False)
